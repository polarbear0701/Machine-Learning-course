# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sample = pd.read_csv('data_train.csv', delimiter = ',')

# %%
sample
# Out:
#             Id  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0            0       0         0          1   24       1       0
# 1            1       0         0          1   28       0       0
# 2            2       0         0          1   36       1       0
# 3            3       0         1          1   35       0       0
# 4            4       0         1          1   27       0       0
# ...        ...     ...       ...        ...  ...     ...     ...
# 202939  202939       0         0          1   29       0       0
# 202940  202940       0         0          1   23       0       0
# 202941  202941       1         1          1   38       0       0
# 202942  202942       0         1          1   22       0       0
# 202943  202943       0         0          1   22       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  ...  MentHlth  PhysHlth  \
# 0                          0             1       0  ...         0         0
# ...

# %%
pd.DataFrame.median(sample)
# Out:
# Id                      101471.5
# HighBP                       0.0
# HighChol                     0.0
# CholCheck                    1.0
# BMI                         27.0
# Smoker                       0.0
# Stroke                       0.0
# HeartDiseaseorAttack         0.0
# PhysActivity                 1.0
# Fruits                       1.0
# Veggies                      1.0
# HvyAlcoholConsump            0.0
# AnyHealthcare                1.0
# NoDocbcCost                  0.0
# GenHlth                      2.0
# MentHlth                     0.0
# PhysHlth                     0.0
# DiffWalk                     0.0
# Sex                          0.0
# Age                          8.0
# Education                    5.0
# Income                       7.0
# ExtraMedTest                 0.0
# ExtraAlcoholTest             0.0
# Status                       0.0
# dtype: float64

# %%
plt.figure()
sample.hist(figsize=(20,15))
plt.show()

# %%
sample.plot(kind='box', subplots=True, layout=(5,5), sharex=False, sharey=False, figsize=(20,15))
plt.show()

# %%
print(sample)
# Out:
#             Id  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0            0       0         0          1   24       1       0
# 1            1       0         0          1   28       0       0
# 2            2       0         0          1   36       1       0
# 3            3       0         1          1   35       0       0
# 4            4       0         1          1   27       0       0
# ...        ...     ...       ...        ...  ...     ...     ...
# 202939  202939       0         0          1   29       0       0
# 202940  202940       0         0          1   23       0       0
# 202941  202941       1         1          1   38       0       0
# 202942  202942       0         1          1   22       0       0
# 202943  202943       0         0          1   22       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  ...  MentHlth  PhysHlth  \
# 0                          0             1       0  ...         0         0
# ...
